# %% [markdown]
# # Concrete Strength Prediction

# %% [markdown]
# ### Importing librararies and loading data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
cm = pd.read_csv("Concrete.csv")

# %%
cm
# Out:
#       cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0      540.0    0.0     0.0  162.0               2.5           1040.0
# 1      540.0    0.0     0.0  162.0               2.5           1055.0
# 2      332.5  142.5     0.0  228.0               0.0            932.0
# 3      332.5  142.5     0.0  228.0               0.0            932.0
# 4      198.6  132.4     0.0  192.0               0.0            978.4
# ...      ...    ...     ...    ...               ...              ...
# 1025   276.4  116.0    90.3  179.6               8.9            870.1
# 1026   322.2    0.0   115.6  196.0              10.4            817.9
# 1027   148.5  139.4   108.6  192.7               6.1            892.4
# 1028   159.1  186.7     0.0  175.6              11.3            989.6
# 1029   260.9  100.5    78.3  200.6               8.6            864.5
#
#       fineaggregate  age  csMPa
# 0             676.0   28  79.99
# 1             676.0   28  61.89
# ...

# %%
cm.describe()
# Out:
#             cement         slag       flyash        water  superplasticizer  \
# count  1030.000000  1030.000000  1030.000000  1030.000000       1030.000000
# mean    281.167864    73.895825    54.188350   181.567282          6.204660
# std     104.506364    86.279342    63.997004    21.354219          5.973841
# min     102.000000     0.000000     0.000000   121.800000          0.000000
# 25%     192.375000     0.000000     0.000000   164.900000          0.000000
# 50%     272.900000    22.000000     0.000000   185.000000          6.400000
# 75%     350.000000   142.950000   118.300000   192.000000         10.200000
# max     540.000000   359.400000   200.100000   247.000000         32.200000
#
#        coarseaggregate  fineaggregate          age        csMPa
# count      1030.000000    1030.000000  1030.000000  1030.000000
# mean        972.918932     773.580485    45.662136    35.817961
# std          77.753954      80.175980    63.169912    16.705742
# ...

# %%
#Checking for null values
cm.isna().sum()           #There are no null values in the dataset
# Out:
# cement              0
# slag                0
# flyash              0
# water               0
# superplasticizer    0
# coarseaggregate     0
# fineaggregate       0
# age                 0
# csMPa               0
# dtype: int64

# %% [markdown]
# ## Checking for Normality

# %%
sns.distplot(cm.cement)      #Not follows normal distribution
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cement', ylabel='Density'>

# %%
sns.distplot(cm.slag)       #Not follows normal distribution
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='slag', ylabel='Density'>

# %%
sns.distplot(cm.flyash)       #Not follows normal distribution
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='flyash', ylabel='Density'>

# %%
sns.distplot(cm.water)      #Not follows normal distribution
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='water', ylabel='Density'>

# %%
sns.distplot(cm.superplasticizer)           #Not follows normal distribution
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='superplasticizer', ylabel='Density'>

# %%
sns.distplot(cm.age)              #Not follows normal distribution
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.distplot(cm.csMPa)         #Nearly normal distribution
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='csMPa', ylabel='Density'>

# %% [markdown]
# ### Box-Plots

# %%
plt.subplots(figsize=(12, 6))
ax = sns.boxplot(data=cm)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'cement'),
#  Text(1, 0, 'slag'),
#  Text(2, 0, 'flyash'),
#  Text(3, 0, 'water'),
#  Text(4, 0, 'superplasticizer'),
#  Text(5, 0, 'coarseaggregate'),
#  Text(6, 0, 'fineaggregate'),
#  Text(7, 0, 'age'),
#  Text(8, 0, 'csMPa')]

# %% [markdown]
# ####  Observations :
#
# Age and fineaggreate has maximum outliers
#
# Water and superplasticizer has few outlier
#
# Features are on different scales so scaling is required for knn and optimization based algorithms

# %% [markdown]
# ### Heatmap to understand correlation among variables

# %%
plt.figure(figsize = (15, 7))
heat = sns.heatmap(cm.corr(), annot = True)
heat
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Observations:
#
# Cement and csMPa show the highest correlation among the correlation between target and predictors
#
# Water and superplasticizer show a strong negative correlation followed by water and fineaggregate. Water appears to be
# strongly correlated with other predictors.

# %% [markdown]
# ## Outlier Treatment

# %%
#Finding outliers using IQR method for age
percentile25 = cm['age'].quantile(0.25)
percentile75 = cm['age'].quantile(0.75)
iqr = percentile75 - percentile25

# %%
upper_limit = percentile75 + 1.5*iqr
lower_limit=  percentile25 - 1.5*iqr
print('upper_limit' , percentile75 + 1.5*iqr)
print('lower_limit' , percentile25 - 1.5*iqr)
# Out:
# upper_limit 129.5
# lower_limit -66.5

# %%
#Finding outliers for age
cm[(cm['age'] > upper_limit) | (cm['age'] < lower_limit)]
# Out:
#      cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 2     332.5  142.5     0.0  228.0               0.0            932.0
# 3     332.5  142.5     0.0  228.0               0.0            932.0
# 4     198.6  132.4     0.0  192.0               0.0            978.4
# 6     380.0   95.0     0.0  228.0               0.0            932.0
# 12    427.5   47.5     0.0  228.0               0.0            932.0
# 17    342.0   38.0     0.0  228.0               0.0            932.0
# 19    475.0    0.0     0.0  228.0               0.0            932.0
# 20    427.5   47.5     0.0  228.0               0.0            932.0
# 23    139.6  209.4     0.0  192.0               0.0           1047.0
# 24    380.0    0.0     0.0  228.0               0.0            932.0
# 25    380.0    0.0     0.0  228.0               0.0            932.0
# 26    380.0   95.0     0.0  228.0               0.0            932.0
# 27    342.0   38.0     0.0  228.0               0.0            932.0
# ...

# %%
#trimming outliers for age
new_cm = cm[(cm['age'] < upper_limit) & (cm['age'] > lower_limit)]
new_cm
# Out:
#       cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0      540.0    0.0     0.0  162.0               2.5           1040.0
# 1      540.0    0.0     0.0  162.0               2.5           1055.0
# 5      266.0  114.0     0.0  228.0               0.0            932.0
# 7      380.0   95.0     0.0  228.0               0.0            932.0
# 8      266.0  114.0     0.0  228.0               0.0            932.0
# ...      ...    ...     ...    ...               ...              ...
# 1025   276.4  116.0    90.3  179.6               8.9            870.1
# 1026   322.2    0.0   115.6  196.0              10.4            817.9
# 1027   148.5  139.4   108.6  192.7               6.1            892.4
# 1028   159.1  186.7     0.0  175.6              11.3            989.6
# 1029   260.9  100.5    78.3  200.6               8.6            864.5
#
#       fineaggregate  age  csMPa
# 0             676.0   28  79.99
# 1             676.0   28  61.89
# ...

# %%
#Finding outliers using IQR method for water
percentile25 = new_cm['water'].quantile(0.25)
percentile75 = new_cm['water'].quantile(0.75)
iqr = percentile75 - percentile25

# %%
upper_limit = percentile75 + 1.5*iqr
lower_limit=  percentile25 - 1.5*iqr
print('upper_limit' , percentile75 + 1.5*iqr)
print('lower_limit' , percentile25 - 1.5*iqr)
# Out:
# upper_limit 232.79999999999998
# lower_limit 124.00000000000003

# %%
#Finding outliers for water
new_cm[(new_cm['water'] > upper_limit) | (new_cm['water'] < lower_limit)]
# Out:
#       cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 224    168.0   42.1   163.8  121.8               5.7           1058.7
# 225    168.0   42.1   163.8  121.8               5.7           1058.7
# 226    168.0   42.1   163.8  121.8               5.7           1058.7
# 227    168.0   42.1   163.8  121.8               5.7           1058.7
# 228    168.0   42.1   163.8  121.8               5.7           1058.7
# 862    140.0  164.0   128.0  237.0               6.0            869.0
# 873    237.0   92.0    71.0  247.0               6.0            853.0
# 936    236.9   91.7    71.5  246.9               6.0            852.9
# 1019   139.7  163.9   127.7  236.7               5.8            868.6
#
#       fineaggregate  age  csMPa
# 224           780.1    3   7.75
# 225           780.1   14  17.82
# 226           780.1   28  24.24
# 227           780.1   56  32.85
# 228           780.1  100  39.23
# 862           656.0   28  35.23
# 873           695.0   28  28.63
# ...

# %%
#Trimming outliers for water
new_cm1 = new_cm[(new_cm['water'] < upper_limit) & (new_cm['water'] > lower_limit)]
new_cm1
# Out:
#       cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0      540.0    0.0     0.0  162.0               2.5           1040.0
# 1      540.0    0.0     0.0  162.0               2.5           1055.0
# 5      266.0  114.0     0.0  228.0               0.0            932.0
# 7      380.0   95.0     0.0  228.0               0.0            932.0
# 8      266.0  114.0     0.0  228.0               0.0            932.0
# ...      ...    ...     ...    ...               ...              ...
# 1025   276.4  116.0    90.3  179.6               8.9            870.1
# 1026   322.2    0.0   115.6  196.0              10.4            817.9
# 1027   148.5  139.4   108.6  192.7               6.1            892.4
# 1028   159.1  186.7     0.0  175.6              11.3            989.6
# 1029   260.9  100.5    78.3  200.6               8.6            864.5
#
#       fineaggregate  age  csMPa
# 0             676.0   28  79.99
# 1             676.0   28  61.89
# ...

# %%
#Finding outliers using IQR method for fineaggregate
percentile25 = new_cm1['fineaggregate'].quantile(0.25)
percentile75 = new_cm1['fineaggregate'].quantile(0.75)
iqr = percentile75 - percentile25

# %%
upper_limit = percentile75 + 1.5*iqr
lower_limit=  percentile25 - 1.5*iqr
print('upper_limit' , percentile75 + 1.5*iqr)
print('lower_limit' , percentile25 - 1.5*iqr)
# Out:
# upper_limit 949.4250000000001
# lower_limit 617.6249999999999

# %%
#Finding outliers for fineaggregate
new_cm1[(new_cm1['fineaggregate'] > upper_limit) | (new_cm1['fineaggregate'] < lower_limit)]
# Out:
#      cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 7     380.0   95.0     0.0  228.0               0.0            932.0
# 9     475.0    0.0     0.0  228.0               0.0            932.0
# 18    380.0   95.0     0.0  228.0               0.0            932.0
# 28    427.5   47.5     0.0  228.0               0.0            932.0
# 29    475.0    0.0     0.0  228.0               0.0            932.0
# 36    237.5  237.5     0.0  228.0               0.0            932.0
# 37    332.5  142.5     0.0  228.0               0.0            932.0
# 38    475.0    0.0     0.0  228.0               0.0            932.0
# 44    427.5   47.5     0.0  228.0               0.0            932.0
# 45    427.5   47.5     0.0  228.0               0.0            932.0
# 48    237.5  237.5     0.0  228.0               0.0            932.0
# 49    380.0   95.0     0.0  228.0               0.0            932.0
# 52    237.5  237.5     0.0  228.0               0.0            932.0
# ...

# %%
#trimming outliers for fineaggregate
new_cm2 = new_cm1[(new_cm1['fineaggregate'] < upper_limit) & (new_cm1['fineaggregate'] > lower_limit)]
new_cm2
# Out:
#       cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0      540.0    0.0     0.0  162.0               2.5           1040.0
# 1      540.0    0.0     0.0  162.0               2.5           1055.0
# 5      266.0  114.0     0.0  228.0               0.0            932.0
# 8      266.0  114.0     0.0  228.0               0.0            932.0
# 10     198.6  132.4     0.0  192.0               0.0            978.4
# ...      ...    ...     ...    ...               ...              ...
# 1025   276.4  116.0    90.3  179.6               8.9            870.1
# 1026   322.2    0.0   115.6  196.0              10.4            817.9
# 1027   148.5  139.4   108.6  192.7               6.1            892.4
# 1028   159.1  186.7     0.0  175.6              11.3            989.6
# 1029   260.9  100.5    78.3  200.6               8.6            864.5
#
#       fineaggregate  age  csMPa
# 0             676.0   28  79.99
# 1             676.0   28  61.89
# ...

# %%
#Finding outliers using IQR method for csMPa
percentile25 = new_cm2['csMPa'].quantile(0.25)
percentile75 = new_cm2['csMPa'].quantile(0.75)
iqr = percentile75 - percentile25

# %%
upper_limit = percentile75 + 1.5*iqr
lower_limit=  percentile25 - 1.5*iqr
print('upper_limit' , percentile75 + 1.5*iqr)
print('lower_limit' , percentile25 - 1.5*iqr)
# Out:
# upper_limit 79.32374999999999
# lower_limit -11.846249999999998

# %%
#Finding outliers for csMPa
new_cm2[(new_cm2['csMPa'] > upper_limit) | (new_cm2['csMPa'] < lower_limit)]
# Out:
#      cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0     540.0    0.0     0.0  162.0               2.5           1040.0
# 153   323.7  282.8     0.0  183.8              10.3            942.7
# 159   389.9  189.0     0.0  145.9              22.0            944.7
# 181   389.9  189.0     0.0  145.9              22.0            944.7
# 381   315.0  137.0     0.0  145.0               5.9           1130.0
#
#      fineaggregate  age  csMPa
# 0            676.0   28  79.99
# 153          659.9   56  80.20
# 159          755.8   56  79.40
# 181          755.8   91  82.60
# 381          745.0   28  81.75

# %%
#Trimmimg outliers for csMPa
new_cm3 = new_cm2[(new_cm2['csMPa'] < upper_limit) & (new_cm2['csMPa'] > lower_limit)]
new_cm3
# Out:
#       cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 1      540.0    0.0     0.0  162.0               2.5           1055.0
# 5      266.0  114.0     0.0  228.0               0.0            932.0
# 8      266.0  114.0     0.0  228.0               0.0            932.0
# 10     198.6  132.4     0.0  192.0               0.0            978.4
# 11     198.6  132.4     0.0  192.0               0.0            978.4
# ...      ...    ...     ...    ...               ...              ...
# 1025   276.4  116.0    90.3  179.6               8.9            870.1
# 1026   322.2    0.0   115.6  196.0              10.4            817.9
# 1027   148.5  139.4   108.6  192.7               6.1            892.4
# 1028   159.1  186.7     0.0  175.6              11.3            989.6
# 1029   260.9  100.5    78.3  200.6               8.6            864.5
#
#       fineaggregate  age  csMPa
# 1             676.0   28  61.89
# 5             670.0   90  47.03
# ...

# %%
#Finding outliers using IQR method for superplasricizer
percentile25 = new_cm3['superplasticizer'].quantile(0.25)
percentile75 = new_cm3['superplasticizer'].quantile(0.75)
iqr = percentile75 - percentile25

# %%
upper_limit = percentile75 + 1.5*iqr
lower_limit=  percentile25 - 1.5*iqr
print('upper_limit' , percentile75 + 1.5*iqr)
print('lower_limit' , percentile25 - 1.5*iqr)
# Out:
# upper_limit 26.375
# lower_limit -15.825000000000001

# %%
#Finding outliers for superplasticizer
new_cm3[(new_cm3['superplasticizer'] > upper_limit) | (new_cm3['superplasticizer'] < lower_limit)]
# Out:
#      cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 76    469.0  117.2     0.0  137.8              32.2            852.1
# 79    531.3    0.0     0.0  141.8              28.2            852.1
# 99    469.0  117.2     0.0  137.8              32.2            852.1
# 102   531.3    0.0     0.0  141.8              28.2            852.1
# 122   469.0  117.2     0.0  137.8              32.2            852.1
# 125   531.3    0.0     0.0  141.8              28.2            852.1
# 145   469.0  117.2     0.0  137.8              32.2            852.1
# 148   531.3    0.0     0.0  141.8              28.2            852.1
# 168   469.0  117.2     0.0  137.8              32.2            852.1
# 171   531.3    0.0     0.0  141.8              28.2            852.1
#
#      fineaggregate  age  csMPa
# 76           840.5    3   40.2
# 79           893.7    3   41.3
# 99           840.5    7   54.9
# 102          893.7    7   46.9
# 122          840.5   28   66.9
# ...

# %%
#Trimming outliers for superplasticizer
new_cm4 = new_cm3[(new_cm3['superplasticizer'] < upper_limit) & (new_cm3['superplasticizer'] > lower_limit)]
new_cm4
# Out:
#       cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 1      540.0    0.0     0.0  162.0               2.5           1055.0
# 5      266.0  114.0     0.0  228.0               0.0            932.0
# 8      266.0  114.0     0.0  228.0               0.0            932.0
# 10     198.6  132.4     0.0  192.0               0.0            978.4
# 11     198.6  132.4     0.0  192.0               0.0            978.4
# ...      ...    ...     ...    ...               ...              ...
# 1025   276.4  116.0    90.3  179.6               8.9            870.1
# 1026   322.2    0.0   115.6  196.0              10.4            817.9
# 1027   148.5  139.4   108.6  192.7               6.1            892.4
# 1028   159.1  186.7     0.0  175.6              11.3            989.6
# 1029   260.9  100.5    78.3  200.6               8.6            864.5
#
#       fineaggregate  age  csMPa
# 1             676.0   28  61.89
# 5             670.0   90  47.03
# ...

# %% [markdown]
# ### Fitiing a Linear regression model to test the hypothesis

# %%
X = new_cm4.drop(['csMPa'],axis=1)
Y = new_cm4['csMPa']

# %%
import statsmodels.api as sm
X = sm.add_constant(X)

# %%
lm = sm.OLS(Y, X).fit()

# %%
y_pred = lm.predict(X)

# %%
residuals = lm.resid

# %% [markdown]
# ## Hypothesis Testing for Linear Regression
#
# Null hypthesis : cofficients of cement	slag,flyash,water,superplasticizer,coarseaggregate,fineaggregate and age = 0
#
# vs
#
# Alternate hypothesis : cofficients of cement,slag,flyash,water,superplasticizer,coarseaggregate,fineaggregate and age <> 0

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  csMPa   R-squared:                       0.773
# Model:                            OLS   Adj. R-squared:                  0.771
# Method:                 Least Squares   F-statistic:                     378.9
# Date:                Thu, 03 Nov 2022   Prob (F-statistic):          3.51e-280
# Time:                        22:58:58   Log-Likelihood:                -3126.4
# No. Observations:                 897   AIC:                             6271.
# Df Residuals:                     888   BIC:                             6314.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Since p value of cofficient of coarseaggregate and fineaggregate > 0.05 these features are not statistically significant at 95% confidence level
# but p value of other cofficients is < 0.05, hence they are statistically significant.

# %%
X = new_cm4.drop(['csMPa','fineaggregate','coarseaggregate'],axis=1)
Y = new_cm4['csMPa']

# %% [markdown]
# # Checking for Assumptions of Linear Regression

# %% [markdown]
# # Linear Relationship between target and predictors

# %%
#Pairwise Scatterplot
from pandas.plotting import scatter_matrix
scatter_matrix(new_cm4,alpha=1,figsize=(25,25),diagonal='hist')
plt.show()

# %% [markdown]
# ### Observation :
# Except for cement no other predictor is showing a linear relationship with csMPa.
# This assumption of Linear Regression is not satisfied

# %% [markdown]
# # No or Little Multicollinearity between independent variables

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
{X.columns[i]:variance_inflation_factor(X.values,i) for i in range(1,X.shape[1])}
# Out:
# {'slag': 3.054389093332904,
#  'flyash': 4.703656637598033,
#  'water': 20.94226847828412,
#  'superplasticizer': 4.89828491209689,
#  'age': 2.2974451249213717}

# %% [markdown]
# Since vif of water = 21.08 it is having a very strong correlation with any feature, 'water' will be dropped

# %%
X = X.drop(['water'],axis=1)

# %% [markdown]
# # Checking for homoscedasticity - constant variance

# %%
residuals = lm.resid
plt.scatter(Y,residuals)
plt.plot(Y,[0]*len(Y))

# %% [markdown]
# A pattern can be seen around the line, hence hetroscedasticity is present.

# %% [markdown]
# ## No autocorelation of errors

# %%
plt.figure(figsize=(20,15))

plt.plot(residuals.index, residuals)

plt.show()

# %% [markdown]
# # Residuals should be normally distributed

# %%
#Residuals are having near to normal distribution
import seaborn as sns
sns.distplot(residuals)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Not all the assumptions of linear regression are not met hence a linear model will not give precise predictins. So I will
# apply linear regression to show that predictions are not precise.

# %% [markdown]
# # Splitting the data into Train-Validation-Test

# %%
from sklearn.model_selection import train_test_split
#Train-test split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30)

# %%
#Train-validation split
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.25)

# %% [markdown]
# ## Standardizing the data for distance based algorithms like KNN and optimization based algorithm

# %%
from sklearn.preprocessing import StandardScaler       #Scaling the data for  linear regression and KNN
scaler = StandardScaler()

X_train1 = pd.DataFrame(scaler.fit_transform(X_train), columns = X_train.columns)
X_valid1 = pd.DataFrame(scaler.transform(X_valid), columns = X_valid.columns)
X_test1= pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

# %% [markdown]
# # Model Building

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train1, y_train)

# %%
y_pred = reg.predict(X_valid1)

# %%
#MAE - Mean Absoulte Error
np.mean(np.abs(y_valid - y_pred))
# Out:
# 7.192101904672201

# %%
#MAPE
np.mean(np.abs(y_valid - y_pred)/y_valid)*100
# Out:
# 25.056413382314158

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

reg_tree = DecisionTreeRegressor(max_depth=7)   #greedy algorithm
reg_tree.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=7)

# %%
y_pred = reg_tree.predict(X_valid)

# %%
#MAE
np.mean(np.abs(y_valid - y_pred))
# Out:
# 5.364588000254487

# %%
#MAPE
np.mean(np.abs(y_valid - y_pred)/y_valid)*100
# Out:
# 16.98778034425937

# %% [markdown]
# ### Hyperparameter tuning - chosing best depth

# %%
depth = np.arange(1,20)
mape=[]

for k in depth:
    reg_tree = DecisionTreeRegressor(max_depth=k)
    reg_tree.fit(X_train,y_train)
    y_pred = reg_tree.predict(X_valid)
    mape.append(np.mean(np.abs(np.mean(np.abs(y_valid - y_pred)/y_valid)*100)))

# %%
plt.plot(depth, np.array(mape))
plt.show()

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=7)

# %%
knn.fit(X_train1,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=7)

# %%
y_pred = knn.predict(X_valid1)

# %%
#MAE
np.mean(np.abs(y_valid - y_pred))
# Out:
# 5.6988626023657885

# %%
#MAPE
np.mean(np.abs(y_valid - y_pred)/y_valid)*100
# Out:
# 18.292099071283197

# %% [markdown]
# ### Hyperparameter tuning - chosing best value of k

# %%
k = np.arange(1,20)
mape=[]

for i in k:
    knn = KNeighborsRegressor(n_neighbors=i)
    knn.fit(X_train1,y_train)
    y_pred = knn.predict(X_valid1)
    mape.append(np.mean(np.abs(np.mean(np.abs(y_valid - y_pred)/y_valid)*100)))

# %%
plt.plot(k, np.array(mape))
plt.show()

# %% [markdown]
# # Final Testing

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_test1, y_test)

# %%
y_pred = reg.predict(X_test1)

# %%
#MAE - Mean Absoulte Error
np.mean(np.abs(y_test - y_pred))
# Out:
# 6.5511666472649575

# %%
#MAPE
np.mean(np.abs(y_test - y_pred)/y_test)*100
# Out:
# 24.674056782564907

# %% [markdown]
# Note : Linear Regression is performing the worst than all the other algorithms because the assumptions of linear regression
#        were not met. Thus the predictions are not precise.

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=7) #Lazy Learner
knn.fit(X_test1,y_test)
# Out:
# KNeighborsRegressor(n_neighbors=7)

# %%
y_pred = knn.predict(X_test1)

# %%
#MAE
np.mean(np.abs(y_test - y_pred))
# Out:
# 5.217582010582013

# %%
#MAPE
np.mean(np.abs(y_test - y_pred)/y_test)*100
# Out:
# 20.215995151202446

# %% [markdown]
# # Decision Tree

# %%
reg_tree = DecisionTreeRegressor(max_depth=7)   #greedy algorithm
reg_tree.fit(X_test,y_test)
# Out:
# DecisionTreeRegressor(max_depth=7)

# %%
y_pred = reg_tree.predict(X_test)

# %%
#MAE
np.mean(np.abs(y_test - y_pred))
# Out:
# 2.4508520473353803

# %%
#MAPE
np.mean(np.abs(y_test - y_pred)/y_test)*100
# Out:
# 8.612172300380513

# %% [markdown]
# # Conclusion

# %% [markdown]
# ### I will finally select Decision Tree as the best model because I am getting the lowest MAE(Mean Abosulte Error) and   MAPE(Mean Abosulte Percentage Error) for this model. Note here that Linear Regression performed the worst out of all the 3 models because the data couldn't fullfill the assumptions of Linear Regression.
